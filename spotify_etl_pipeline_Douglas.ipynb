# %%
#!pip install spotipy

# %%
import spotipy
import sys
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="8051f652c4664c0ba1c816d24fa7d95f",client_secret="f3e5068a0d5d4ff2b735e0bb40e0f87c")

# %%
#Conects with Spotify Data 
sp =  spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link ="https://open.spotify.com/playlist/5S8ZLwh1za24YM3Ih1Mvjt"

# %%
playlist_link
# Out:
# 'https://open.spotify.com/playlist/5S8ZLwh1za24YM3Ih1Mvjt'

# %%
playlist_uri = playlist_link.split("/")[-1].split("?")[0]

# %%
playlist_uri
# Out:
# '5S8ZLwh1za24YM3Ih1Mvjt'

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data["items"][0]["track"]["album"]["id"]
# Out:
# '4troiZxuVOiGbqC3HrjspQ'

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5S8ZLwh1za24YM3Ih1Mvjt/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-08-09T03:51:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/3mqubr2p0c0i0qgc3pdaagw8p'},
#     'href': 'https://api.spotify.com/v1/users/3mqubr2p0c0i0qgc3pdaagw8p',
#     'id': '3mqubr2p0c0i0qgc3pdaagw8p',
#     'type': 'user',
#     'uri': 'spotify:user:3mqubr2p0c0i0qgc3pdaagw8p'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
# ...

# %%
data["items"][0]["track"]["album"]["name"]
# Out:
# 'Orange Juice'

# %%
data["items"][0]["track"]["album"]["release_date"]
# Out:
# '2014-01-20'

# %%
data["items"][0]["track"]["album"]["total_tracks"]
# Out:
# 2

# %%
album_list = []
for row in data["items"]:
    album_id = row["track"]["album"]["id"]
    album_name = row["track"]["album"]["name"]
    album_realease_date = row["track"]["album"]["release_date"]
    album_total_tracks = row["track"]["album"]["total_tracks"]
    album_elements = {'album_id': album_id, 'name': album_name, 'realease_date': album_realease_date, 'total_tracks': album_total_tracks}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '4troiZxuVOiGbqC3HrjspQ',
#   'name': 'Orange Juice',
#   'realease_date': '2014-01-20',
#   'total_tracks': 2},
#  {'album_id': '2AwtTIdUFaUl69alioeFut',
#   'name': 'Alucinacao',
#   'realease_date': '1976-01-01',
#   'total_tracks': 10},
#  {'album_id': '2p9gK2BcdrloHNJwarc9gc',
#   'name': 'death bed (coffee for your head)',
#   'realease_date': '2020-02-08',
#   'total_tracks': 1},
#  {'album_id': '0d9km1VogLi6sN6S95ilyT',
#   'name': 'Abaixo de Zero: Hello Hell',
#   'realease_date': '2019-04-12',
#   'total_tracks': 9},
#  {'album_id': '7Jeqys8tnH1taEcqpKElYD',
#   'name': 'Pequeno mapa do tempo: Belchior 70 anos',
#   'realease_date': '2017-05-12',
#   'total_tracks': 14},
#  {'album_id': '7JV505O1I9Sc3uHtFEFtkf',
#   'name': 'Notion',
#   'realease_date': '2017-03-01',
#   'total_tracks': 6},
#  {'album_id': '0d9km1VogLi6sN6S95ilyT',
#   'name': 'Abaixo de Zero: Hello Hell',
#   'realease_date': '2019-04-12',
#   'total_tracks': 9},
# ...

# %%
import pandas as pd
album_list_pd = pd.DataFrame(album_list)

# %%
album_list_pd
# Out:
#                   album_id                                     name  \
# 0   4troiZxuVOiGbqC3HrjspQ                             Orange Juice
# 1   2AwtTIdUFaUl69alioeFut                               Alucinacao
# 2   2p9gK2BcdrloHNJwarc9gc         death bed (coffee for your head)
# 3   0d9km1VogLi6sN6S95ilyT               Abaixo de Zero: Hello Hell
# 4   7Jeqys8tnH1taEcqpKElYD  Pequeno mapa do tempo: Belchior 70 anos
# ..                     ...                                      ...
# 95  464SZoogrWpjVuXXnLYBwp                                  Carbono
# 96  18gEdE7EJMpVeBCSDZgOdG                               Na Pressão
# 97  00yNAB6doky2wizrXstFaN                                  Labiata
# 98  1979ERApWz1wTn3AgY3Wcz                        last day on earth
# 99  5qDjJnxitiOrUanwwtaIYd             It's a beautiful day (Cover)
#
#    realease_date  total_tracks
# 0     2014-01-20             2
# 1     1976-01-01            10
# 2     2020-02-08             1
# ...

# %%
pd_data['total_tracks'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 pd_data['total_tracks'].sum()
#
# NameError: name 'pd_data' is not defined

# %%
pd_data.groupby(['realease_date'])['total_tracks'].count().sort_values(ascending=False).head(10)

# %%
#api de dados do portal da transparencia governom
#09b4e68c7bfc3aad0fd20110dec73ff8

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rj3M9qmjkCvStwlulF3jx'},
#   'href': 'https://api.spotify.com/v1/artists/5rj3M9qmjkCvStwlulF3jx',
#   'id': '5rj3M9qmjkCvStwlulF3jx',
#   'name': 'Stanley Brinks and The Wave Pictures',
#   'type': 'artist',
#   'uri': 'spotify:artist:5rj3M9qmjkCvStwlulF3jx'}]

# %%
artist_list = []

for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in (value['artists']):
                artist_dict = {
                 'artist_id': artist['id'],
                 'artist_name': artist['name'],
                 'external_urls': artist['external_urls']
                }
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5rj3M9qmjkCvStwlulF3jx',
#   'artist_name': 'Stanley Brinks and The Wave Pictures',
#   'external_urls': {'spotify': 'https://open.spotify.com/artist/5rj3M9qmjkCvStwlulF3jx'}},
#  {'artist_id': '0C8HhyOa7zfzIl3gmPjY52',
#   'artist_name': 'Belchior',
#   'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8HhyOa7zfzIl3gmPjY52'}},
#  {'artist_id': '6bmlMHgSheBauioMgKv2tn',
#   'artist_name': 'Powfu',
#   'external_urls': {'spotify': 'https://open.spotify.com/artist/6bmlMHgSheBauioMgKv2tn'}},
#  {'artist_id': '35l9BRT7MXmM8bv2WDQiyB',
#   'artist_name': 'beabadoobee',
#   'external_urls': {'spotify': 'https://open.spotify.com/artist/35l9BRT7MXmM8bv2WDQiyB'}},
#  {'artist_id': '6aCbXH85qN6xo54C7atSMx',
#   'artist_name': 'Black Alien',
#   'external_urls': {'spotify': 'https://open.spotify.com/artist/6aCbXH85qN6xo54C7atSMx'}},
#  {'artist_id': '0C8HhyOa7zfzIl3gmPjY52',
#   'artist_name': 'Belchior',
# ...

# %%
artist_data = pd.DataFrame(artist_list)

# %%
artist_data
# Out:
#                   artist_id                           artist_name  \
# 0    5rj3M9qmjkCvStwlulF3jx  Stanley Brinks and The Wave Pictures
# 1    0C8HhyOa7zfzIl3gmPjY52                              Belchior
# 2    6bmlMHgSheBauioMgKv2tn                                 Powfu
# 3    35l9BRT7MXmM8bv2WDQiyB                           beabadoobee
# 4    6aCbXH85qN6xo54C7atSMx                           Black Alien
# ..                      ...                                   ...
# 123  4YLBdrR3DVSMncm785NH6C                                Lenine
# 124  4YLBdrR3DVSMncm785NH6C                                Lenine
# 125  2kCO8LXN1usaOPL3iEE28I                            Tai Verdes
# 126  0RvjLz7klSc5lNgxX7EiVZ                          Trinix Remix
# 127  7IawSha4HcyAilPrgpVREn                               Rushawn
#
#                                          external_urls
# 0    {'spotify': 'https://open.spotify.com/artist/5...
# 1    {'spotify': 'https://open.spotify.com/artist/0...
# ...

# %%
album_list_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   album_id       100 non-null    object
#  1   name           100 non-null    object
#  2   realease_date  100 non-null    object
#  3   total_tracks   100 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
album_list_pd = album_list_pd.drop_duplicates(subset=['album_id'])

# %%
album_list_pd
# Out:
#                   album_id                                     name  \
# 0   4troiZxuVOiGbqC3HrjspQ                             Orange Juice
# 1   2AwtTIdUFaUl69alioeFut                               Alucinacao
# 2   2p9gK2BcdrloHNJwarc9gc         death bed (coffee for your head)
# 3   0d9km1VogLi6sN6S95ilyT               Abaixo de Zero: Hello Hell
# 4   7Jeqys8tnH1taEcqpKElYD  Pequeno mapa do tempo: Belchior 70 anos
# ..                     ...                                      ...
# 95  464SZoogrWpjVuXXnLYBwp                                  Carbono
# 96  18gEdE7EJMpVeBCSDZgOdG                               Na Pressão
# 97  00yNAB6doky2wizrXstFaN                                  Labiata
# 98  1979ERApWz1wTn3AgY3Wcz                        last day on earth
# 99  5qDjJnxitiOrUanwwtaIYd             It's a beautiful day (Cover)
#
#    realease_date  total_tracks
# 0     2014-01-20             2
# 1     1976-01-01            10
# 2     2020-02-08             1
# ...

# %%
artist_data = artist_data.drop_duplicates(subset=['artist_id'])

# %%
artist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 0 to 127
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artist_id      85 non-null     object
#  1   artist_name    85 non-null     object
#  2   external_urls  85 non-null     object
# dtypes: object(3)
# memory usage: 2.7+ KB

# %%
data['items'][0]['track']['id']
# Out:
# '2PkC4vf6KE4lPMea6Ce20c'

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added =row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id': song_id, 'song_name':song_name, 'song_duration': song_duration,
                    'song_url': song_url,'song_popularity':song_popularity, 'song_added':song_added,
                    'album_id':album_id,'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2PkC4vf6KE4lPMea6Ce20c',
#   'song_name': 'Orange Juice',
#   'song_duration': 200149,
#   'song_url': 'https://open.spotify.com/track/2PkC4vf6KE4lPMea6Ce20c',
#   'song_popularity': 38,
#   'song_added': '2020-08-09T03:51:55Z',
#   'album_id': '4troiZxuVOiGbqC3HrjspQ',
#   'artist_id': '5rj3M9qmjkCvStwlulF3jx'},
#  {'song_id': '6lCcA1ugWuQPBCHXecSwc8',
#   'song_name': 'Alucinação',
#   'song_duration': 294360,
#   'song_url': 'https://open.spotify.com/track/6lCcA1ugWuQPBCHXecSwc8',
#   'song_popularity': 52,
#   'song_added': '2020-08-09T03:52:01Z',
#   'album_id': '2AwtTIdUFaUl69alioeFut',
#   'artist_id': '0C8HhyOa7zfzIl3gmPjY52'},
#  {'song_id': '7eJMfftS33KTjuF7lTsMCx',
#   'song_name': 'death bed (coffee for your head)',
#   'song_duration': 173333,
#   'song_url': 'https://open.spotify.com/track/7eJMfftS33KTjuF7lTsMCx',
#   'song_popularity': 81,
#   'song_added': '2020-08-09T03:52:06Z',
#   'album_id': '2p9gK2BcdrloHNJwarc9gc',
# ...
